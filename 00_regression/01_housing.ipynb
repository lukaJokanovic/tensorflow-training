# %%
# !pip install -q -U keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 2.4 MB/s eta 0:00:00

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import keras_tuner as kt


column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in data.items():
    sns.boxplot(y=k, data=data, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# There is a lot of outliers. We should check the percentage of them

# %%
for k, v in data.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    irq = q3 - q1
    outside = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
    perc = outside.shape[0] / data.shape[0] * 100.0
    print("Column %s outliers = %.2f%%" % (k, perc))
# Out:
# Column CRIM outliers = 13.04%
# Column ZN outliers = 13.44%
# Column INDUS outliers = 0.00%
# Column CHAS outliers = 100.00%
# Column NOX outliers = 0.00%
# Column RM outliers = 5.93%
# Column AGE outliers = 0.00%
# Column DIS outliers = 0.99%
# Column RAD outliers = 0.00%
# Column TAX outliers = 0.00%
# Column PTRATIO outliers = 2.96%
# Column B outliers = 15.22%
# Column LSTAT outliers = 1.38%
# Column MEDV outliers = 7.91%

# %% [markdown]
# Removing MEDV outliers

# %%
data = data[~(data['MEDV'] >= 40.0)]

# %%
data.shape
# Out:
# (475, 14)

# %% [markdown]
# Visualizing features and target(MEDV) distribution

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in data.items():
    sns.histplot(v, ax=axs[index],kde=True,stat="density", kde_kws=dict(cut=3))
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# A lot of features along with target have eather normal od bimodel distribution.
# CRIM, ZN and B have highly skewed distributions.
# CHAS is discrete.

# %% [markdown]
# Lets see their correlaton

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(data.corr().abs(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From correlation matrix, we see TAX and RAD are highly correlated features. The columns LSTAT, INDUS, RM, TAX, NOX, PTRAIO has a correlation score above 0.5 with MEDV which is a good indication of using as predictors. Let's plot these columns against MEDV.

# %%
from sklearn import preprocessing
# Let's scale the columns before plotting them against MEDV
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX', 'DIS', 'AGE']
X = data.loc[:,column_sels]
y = data['MEDV']
X = pd.DataFrame(data=min_max_scaler.fit_transform(X), columns=column_sels)

# %%
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=X[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
y =  np.log1p(y)
for col in X.columns:
    if np.abs(X[col].skew()) > 0.3:
        X[col] = np.log1p(X[col])

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in X.items():
    sns.histplot(v, ax=axs[index],kde=True,stat="density", kde_kws=dict(cut=3))
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size = 0.25,random_state = 42 , shuffle = False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (356, 8)
# (119, 8)
# (356,)
# (119,)

# %%
def model_build(hp):
  model = tf.keras.Sequential()

  counter = 0
  for i in range(hp.Int("num_layers" , min_value=1 , max_value=4)):
    if counter == 0:
      model.add(tf.keras.layers.Dense(hp.Int("units" + str(i) , min_value = 8 , max_value = 128 , step = 8),
                                      activation = hp.Choice("activation" + str(i) ,values = ["relu","tanh","sigmoid"]),
                                      input_dim = 8))
    else:
      model.add(tf.keras.layers.Dense(hp.Int("units" + str(i) , min_value = 8 , max_value = 128 , step = 8),
                                      activation = hp.Choice("activation" + str(i) ,values = ["relu","tanh","sigmoid"]),
                                      input_dim = 8))
      if hp.Boolean("bool" + str(i)):
        model.add(tf.keras.layers.Dropout(hp.Choice("Dropout " + str(i) , values = [0.15,0.20,0.25,0.30])))

    counter += 1

  model.add(tf.keras.layers.Dense(1 , activation = None))

  model.compile(optimizer = hp.Choice("optimizer", values = ["adam","sgd","adagrad","rmsprop"]),
                  loss = "mae",
                  metrics = ["mae"])

  return model

# %%
tuner = kt.RandomSearch(model_build, objective = 'val_loss', max_trials = 15)

# %%
tuner.search(X_train ,y_train, epochs = 10, validation_data = (X_test , y_test))
# Out:
# Trial 15 Complete [00h 00m 03s]
# val_loss: 1.8545931577682495
#
# Best val_loss So Far: 0.2746294140815735
# Total elapsed time: 00h 00m 46s

# %%
best_hp = tuner.get_best_hyperparameters()[0].values
best_hp
# Out:
# {'num_layers': 2,
#  'units0': 96,
#  'activation0': 'sigmoid',
#  'optimizer': 'rmsprop',
#  'units1': 40,
#  'activation1': 'tanh',
#  'bool1': False,
#  'Dropout 1': 0.25}

# %%
# model = tuner.get_best_models(num_models = 1)[0]
# early = tf.keras.callbacks.EarlyStopping(
#     monitor = "val_loss",
#     min_delta = 0.0001,
#     patience = 20,
#     verbose = True,
#     mode = "auto",
#     baseline = None,
#     restore_best_weights = True)
# Model = model.fit(X_train,y_train , epochs = 200, initial_epoch = 40 , validation_split = 0.25 , callbacks = early)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(96, activation = "sigmoid", input_dim = 8))
model.add(tf.keras.layers.Dense(40, activation = "tanh"))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(1 , activation = None))

model.compile(optimizer = "rmsprop", loss = "mae", metrics = ["mae"])

history = model.fit(X_train,y_train , epochs = 200)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 3ms/step - loss: 1.0929 - mae: 1.0929
# Epoch 2/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3796 - mae: 0.3796
# Epoch 3/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4203 - mae: 0.4203
# Epoch 4/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4242 - mae: 0.4242
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3867 - mae: 0.3867
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3677 - mae: 0.3677
# Epoch 7/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3545 - mae: 0.3545
# Epoch 8/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3670 - mae: 0.3670
# Epoch 9/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3371 - mae: 0.3371
# Epoch 10/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3377 - mae: 0.3377
# Epoch 11/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3220 - mae: 0.3220
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3169 - mae: 0.3169
# Epoch 13/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3304 - mae: 0.3304
# Epoch 14/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3017 - mae: 0.3017
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3589 - mae: 0.3589
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3164 - mae: 0.3164
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3258 - mae: 0.3258
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2785 - mae: 0.2785
# Epoch 19/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3337 - mae: 0.3337
# Epoch 20/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3090 - mae: 0.3090
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2918 - mae: 0.2918
# Epoch 22/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3143 - mae: 0.3143
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2976 - mae: 0.2976
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3035 - mae: 0.3035
# Epoch 25/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3111 - mae: 0.3111
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2897 - mae: 0.2897
# Epoch 27/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2982 - mae: 0.2982
# Epoch 28/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3102 - mae: 0.3102
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3092 - mae: 0.3092
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2903 - mae: 0.2903
# Epoch 31/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3033 - mae: 0.3033
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2852 - mae: 0.2852
# Epoch 33/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2916 - mae: 0.2916
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2766 - mae: 0.2766
# Epoch 35/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3256 - mae: 0.3256
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2697 - mae: 0.2697
# Epoch 37/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2988 - mae: 0.2988
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2974 - mae: 0.2974
# Epoch 39/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3022 - mae: 0.3022
# Epoch 40/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2941 - mae: 0.2941
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3139 - mae: 0.3139
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2959 - mae: 0.2959
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3186 - mae: 0.3186
# Epoch 44/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2674 - mae: 0.2674
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2911 - mae: 0.2911
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2824 - mae: 0.2824
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2872 - mae: 0.2872
# Epoch 48/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2935 - mae: 0.2935
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2843 - mae: 0.2843
# Epoch 50/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2917 - mae: 0.2917
# Epoch 51/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2786 - mae: 0.2786
# Epoch 52/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2762 - mae: 0.2762
# Epoch 53/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2882 - mae: 0.2882
# Epoch 54/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2727 - mae: 0.2727
# Epoch 55/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3089 - mae: 0.3089
# Epoch 56/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2880 - mae: 0.2880
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2751 - mae: 0.2751
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2786 - mae: 0.2786
# Epoch 59/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2750 - mae: 0.2750
# Epoch 60/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2661 - mae: 0.2661
# Epoch 61/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2888 - mae: 0.2888
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2721 - mae: 0.2721
# Epoch 63/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2880 - mae: 0.2880
# Epoch 64/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2615 - mae: 0.2615
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2987 - mae: 0.2987
# Epoch 66/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2773 - mae: 0.2773
# Epoch 67/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2930 - mae: 0.2930
# Epoch 68/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2724 - mae: 0.2724
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2817 - mae: 0.2817
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2995 - mae: 0.2995
# Epoch 71/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2826 - mae: 0.2826
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3042 - mae: 0.3042
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2682 - mae: 0.2682
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2908 - mae: 0.2908
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2913 - mae: 0.2913
# Epoch 76/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2814 - mae: 0.2814
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2824 - mae: 0.2824
# Epoch 78/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2712 - mae: 0.2712
# Epoch 79/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2864 - mae: 0.2864
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2694 - mae: 0.2694
# Epoch 81/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2434 - mae: 0.2434
# Epoch 82/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2885 - mae: 0.2885
# Epoch 83/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2672 - mae: 0.2672
# Epoch 84/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2868 - mae: 0.2868
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2749 - mae: 0.2749
# Epoch 86/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3013 - mae: 0.3013
# Epoch 87/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2847 - mae: 0.2847
# Epoch 88/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2726 - mae: 0.2726
# Epoch 89/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2867 - mae: 0.2867
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2671 - mae: 0.2671
# Epoch 91/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2679 - mae: 0.2679
# Epoch 92/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2603 - mae: 0.2603
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2594 - mae: 0.2594
# Epoch 94/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2757 - mae: 0.2757
# Epoch 95/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2811 - mae: 0.2811
# Epoch 96/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2597 - mae: 0.2597
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2695 - mae: 0.2695
# Epoch 98/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2785 - mae: 0.2785
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2667 - mae: 0.2667
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2563 - mae: 0.2563
# Epoch 101/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2752 - mae: 0.2752
# Epoch 102/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2592 - mae: 0.2592
# Epoch 103/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2681 - mae: 0.2681
# Epoch 104/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2527 - mae: 0.2527
# Epoch 105/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2574 - mae: 0.2574
# Epoch 106/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2680 - mae: 0.2680
# Epoch 107/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2810 - mae: 0.2810
# Epoch 108/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2671 - mae: 0.2671
# Epoch 109/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2720 - mae: 0.2720
# Epoch 110/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2616 - mae: 0.2616
# Epoch 111/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2699 - mae: 0.2699
# Epoch 112/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2624 - mae: 0.2624
# Epoch 113/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2565 - mae: 0.2565
# Epoch 114/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2781 - mae: 0.2781
# Epoch 115/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2653 - mae: 0.2653
# Epoch 116/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2767 - mae: 0.2767
# Epoch 117/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2834 - mae: 0.2834
# Epoch 118/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2531 - mae: 0.2531
# Epoch 119/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2544 - mae: 0.2544
# Epoch 120/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2893 - mae: 0.2893
# Epoch 121/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2545 - mae: 0.2545
# Epoch 122/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2762 - mae: 0.2762
# Epoch 123/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2386 - mae: 0.2386
# Epoch 124/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2661 - mae: 0.2661
# Epoch 125/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2629 - mae: 0.2629
# Epoch 126/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2530 - mae: 0.2530
# Epoch 127/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2774 - mae: 0.2774
# Epoch 128/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2465 - mae: 0.2465
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2463 - mae: 0.2463
# Epoch 130/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2553 - mae: 0.2553
# Epoch 131/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2520 - mae: 0.2520
# Epoch 132/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2575 - mae: 0.2575
# Epoch 133/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2670 - mae: 0.2670
# Epoch 134/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2704 - mae: 0.2704
# Epoch 135/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2615 - mae: 0.2615
# Epoch 136/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2678 - mae: 0.2678
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2458 - mae: 0.2458
# Epoch 138/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2561 - mae: 0.2561
# Epoch 139/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2641 - mae: 0.2641
# Epoch 140/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2591 - mae: 0.2591
# Epoch 141/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2529 - mae: 0.2529
# Epoch 142/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2626 - mae: 0.2626
# Epoch 143/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2623 - mae: 0.2623
# Epoch 144/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2409 - mae: 0.2409
# Epoch 145/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2600 - mae: 0.2600
# Epoch 146/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2824 - mae: 0.2824
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2729 - mae: 0.2729
# Epoch 148/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2643 - mae: 0.2643
# Epoch 149/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2673 - mae: 0.2673
# Epoch 150/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2458 - mae: 0.2458
# Epoch 151/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2613 - mae: 0.2613
# Epoch 152/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2553 - mae: 0.2553
# Epoch 153/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2357 - mae: 0.2357
# Epoch 154/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2463 - mae: 0.2463
# Epoch 155/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2784 - mae: 0.2784
# Epoch 156/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2546 - mae: 0.2546
# Epoch 157/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2531 - mae: 0.2531
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2804 - mae: 0.2804
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2400 - mae: 0.2400
# Epoch 160/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2517 - mae: 0.2517
# Epoch 161/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2283 - mae: 0.2283
# Epoch 162/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2714 - mae: 0.2714
# Epoch 163/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2597 - mae: 0.2597
# Epoch 164/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2560 - mae: 0.2560
# Epoch 165/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2522 - mae: 0.2522
# Epoch 166/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2329 - mae: 0.2329
# Epoch 167/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2524 - mae: 0.2524
# Epoch 168/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2474 - mae: 0.2474
# Epoch 169/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2678 - mae: 0.2678
# Epoch 170/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2548 - mae: 0.2548
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2472 - mae: 0.2472
# Epoch 172/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2516 - mae: 0.2516
# Epoch 173/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2572 - mae: 0.2572
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2586 - mae: 0.2586
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2356 - mae: 0.2356
# Epoch 176/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2434 - mae: 0.2434
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2523 - mae: 0.2523
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2437 - mae: 0.2437
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2580 - mae: 0.2580
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2572 - mae: 0.2572
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2540 - mae: 0.2540
# Epoch 182/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2383 - mae: 0.2383
# Epoch 183/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2487 - mae: 0.2487
# Epoch 184/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2562 - mae: 0.2562
# Epoch 185/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2407 - mae: 0.2407
# Epoch 186/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2471 - mae: 0.2471
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2505 - mae: 0.2505
# Epoch 188/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2326 - mae: 0.2326
# Epoch 189/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2623 - mae: 0.2623
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2548 - mae: 0.2548
# Epoch 191/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2302 - mae: 0.2302
# Epoch 192/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2368 - mae: 0.2368
# Epoch 193/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2511 - mae: 0.2511
# Epoch 194/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2499 - mae: 0.2499
# Epoch 195/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2412 - mae: 0.2412
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2410 - mae: 0.2410
# Epoch 197/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2538 - mae: 0.2538
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2561 - mae: 0.2561
# Epoch 199/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2373 - mae: 0.2373
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2572 - mae: 0.2572

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 96)                864
#
#  dense_4 (Dense)             (None, 40)                3880
#
#  dropout (Dropout)           (None, 40)                0
#
#  dense_5 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 4785 (18.69 KB)
# Trainable params: 4785 (18.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mae'])

# %%
plt.plot(history.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Model Loss")
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
tf.squeeze(y_pred) - y_test
# Out:
# <tf.Tensor: shape=(119,), dtype=float32, numpy=
# array([-0.03981614, -0.32926798, -0.24195194, -0.40335655, -0.8037338 ,
#        -0.19842482, -0.22991896, -0.20495129, -0.19241524, -0.19123554,
#         0.08639407,  0.35491943,  0.2221781 ,  0.36478376,  0.2854991 ,
#        -0.1787889 ,  0.07155919, -0.04335451,  0.4944377 , -0.415591  ,
#        -0.8835707 , -0.66236544, -0.8866861 , -0.23318458, -0.48285294,
#        -0.91481876, -0.56040144, -0.1152873 ,  0.15203094,  0.2053361 ,
#        -0.23879457,  0.05994582,  0.16314864, -0.39495683, -0.29148006,
#        -0.640754  , -0.3420155 , -0.15113306,  0.04526234,  0.03807187,
#         0.01071262, -0.12288642, -0.02596855, -0.29458904, -0.26384878,
#        -0.27703524, -0.27256393, -0.09142375, -0.31560946,  0.06603384,
#        -0.01414824, -0.10115933, -0.35496736, -0.14192581, -0.5041311 ,
#        -0.54039884, -0.3858385 , -0.19497919, -0.22191596, -0.35049272,
#        -0.18246388, -0.3235953 , -0.24359798, -0.20713139, -0.34373617,
#        -0.42017388, -0.40758705, -0.33609605, -0.287035  , -0.26297593,
#        -0.28690767, -0.3336308 , -0.6036656 , -0.38831758, -0.45723295,
#        -0.54294467, -0.49185658, -0.6128092 , -0.5920191 , -0.6093588 ,
#        -0.6699188 , -0.61495185, -0.6092062 , -0.61091375, -0.5259552 ,
#        -0.6857927 , -0.81283   , -0.36309147, -0.35184598, -0.4486146 ,
#        -0.35385704, -0.33828998, -0.5934799 , -0.62419605, -0.5481472 ,
#        -0.55803704, -0.60721827, -0.6002455 , -0.546556  , -0.56317043,
#        -0.5561805 , -0.49207664,  0.10892773, -0.13920903, -0.34248376,
#        -0.6201248 , -0.4700098 , -0.58128977, -0.61901236, -0.5931177 ,
#        -0.36154628, -0.44130135, -0.34843612, -0.25933242, -0.3761866 ,
#        -0.32873535, -0.32660627, -0.28645563,  0.1945765 ], dtype=float32)>

# %%
np.mean(y_test), np.median(y_test)
# Out:
# (2.729007575619203, 2.766319109226186)
